# %%
import pdfplumber

# %%
pdf = pdfplumber.open('BBP 20_Bebauungsplan.pdf')

# %%
print(pdf.pages[0].extract_text())
# Out:
# Textliche Festsetzungen Planzeichnung Planzeichenerklärung Kennzeichnungen
# (§ 9 Abs. 5 BauGB )
# 1. Art der baulichen Nutzung (§ 9 Abs. 1 Nr. 1 BauGB)
# Sichtdreiecke
# 1. Art der baulichen Nutzung
# 1.1 Ausschluss von allgemein zulässigen Nutzungen (§ 9 Abs. 1 Nr. 1 BauGB i.V.m. § 1 Abs. 5 BauNVO) Im Bebauungsplan sind im Kreuzungsbereich Rottumer Straße / Bundesstraße B 70 und im Bereich der Einmündung der
# 10
# 1.1.1 In den Gewerbe- und Industriegebieten sind die in § 8 Abs. 2 Nr. 3 sowie § 9 Abs. 2 Nr. 2 genannten Nutzungen Butterkuhle 6 GE Gewerbegebiet (§ 8 BauNVO) Straße Zur Kiesgrube in die Bundesstraße B 70 zur Gewährleistung einer freien Sicht in die Bundesstraße B 70
# (Tankstellen) nicht zulässig. freizuhaltende Sichtdreiecke gekennzeichnet.
# GI Industriegebiet (§ 9 BauNVO)
# 1.1.2 In den Gewerbe- und Industriegebieten sind die in die folgenden Gewerbebetriebe nicht zulässig:
# 2. Maß der baulichen Nutzung
# ...
